# %%
import torch
import json
import argparse
import os
import monai
import pandas as pd
import numpy as np

from dev.data.dataset_csv import CSVDataset
from adrd.model import ADRDModel
from tqdm import tqdm
from collections import defaultdict

# %%
# change the train, vld and test file paths, new cnf_file path
basedir = '.'
data_path="/home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/data/adni_data_single.csv" # path to the data file before train val test split
train_path="/home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/data/adni_train_split_single.csv"
vld_path="/home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/data/adni_val_split_single.csv"
test_path="/home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/data/a4_test_split_single.csv"
cnf_file="/home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/meta_files/ab_tau_config_finetune.toml"
orig_ckpt_path = '/data_1/skowshik/ckpts_backbone_swinunet/ckpt_without_imaging.pt'
new_ckpt_path = f'{basedir}/dev/ckpt/model_ckpt_finetune.pt'

# no need to change these as they will not be used with non-imaging model
emb_path = '/data_1/dlteif/SwinUNETR_MRI_stripped_MNI_emb/' 
nacc_mri_info = "dev/nacc_mri_3d.json"
other_mri_info = "dev/other_3d_mris.json"

img_net="NonImg"
img_mode=-1
mri_type="SEQ"

# these are labels to remove from the model's state dictionary
labels_to_remove = ['NC', 'MCI', 'DE', 'AD', 'LBD', 'VD', 'PRD', 'FTD', 'NPH', 'SEF', 'PSY', 'TBI', 'ODE']

# add the new labels
new_labels = ['amy_label', 'tau_label']

# %%
train_path
# Out:
# '/home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/data/adni_train_split_single.csv'

# %%
state_dict = torch.load(orig_ckpt_path, map_location=torch.device('cpu'))
if 'state_dict' in state_dict:
    state_dict = state_dict['state_dict']
else:
    src_modalities = state_dict.pop('src_modalities')
    tgt_modalities = state_dict.pop('tgt_modalities')
    if 'label_distribution' in state_dict:
        label_distribution = state_dict.pop('label_distribution')
    if 'optimizer' in state_dict:
        optimizer = state_dict.pop('optimizer')
    d_model = state_dict.pop('d_model')
    nhead = state_dict.pop('nhead')
    num_encoder_layers = state_dict.pop('num_encoder_layers')
    num_decoder_layers = state_dict.pop('num_decoder_layers')
    if 'epoch' in state_dict.keys():
        start_epoch = state_dict.pop('epoch')
    img_net = state_dict.pop('img_net')
    imgnet_layers = state_dict.pop('imgnet_layers')
    img_size = state_dict.pop('img_size')
    patch_size = state_dict.pop('patch_size')
    imgnet_ckpt = state_dict.pop('imgnet_ckpt')
    train_imgnet = state_dict.pop('train_imgnet')
    if 'scaler' in state_dict and state_dict['scaler']:
        state_dict.pop('scaler')

# %% [markdown]
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# initialize datasets
seed = 0
stripped = '_stripped_MNI'
print("Loading training dataset ... ")
dat_trn = CSVDataset(dat_file=train_path, cnf_file=cnf_file, mode=0, img_mode=img_mode, mri_type=mri_type, arch=img_net, emb_path=emb_path, nacc_mri_info=nacc_mri_info, other_3d_mris=other_mri_info, transforms=None, stripped=stripped)
print("Done.\nLoading Validation dataset ...")
dat_vld = CSVDataset(dat_file=vld_path, cnf_file=cnf_file, mode=1, img_mode=img_mode, mri_type=mri_type, arch=img_net, emb_path=emb_path, nacc_mri_info=nacc_mri_info, other_3d_mris=other_mri_info, transforms=None, stripped=stripped)
# print("Done.\nLoading testing dataset ...")
# dat_tst = CSVDataset(dat_file=test_path, cnf_file=cnf_file, mode=2, img_mode=img_mode, mri_type=mri_type, arch=img_net, emb_path=emb_path, nacc_mri_info=nacc_mri_info, other_mri_info=other_mri_info, transforms=None, stripped=stripped)
# print("Done.")
# Out:
# Loading training dataset ...
# /home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/data/adni_train_split_single.csv
# AVAILABLE MRI Cohorts:  set()
# NACC MRIs not available
# Avail mris: 0
# 1262 are selected for mode 0.
# Out of 107 features in configuration file, [] are unavailable in data file.
# Out of 2 labels in configuration file, 0 are unavailable in data file.
# Total mri embeddings found: {}
# Total mri embeddings found: 0
# Out of 1262 samples, 0 are dropped due to complete feature missing.
# Out of 1262 samples, 0 are dropped due to complete label missing.
# Done.
# Loading Validation dataset ...
# /home/varunaja/mri_pet/adrd_tool_varuna/adrd_transformer/data/adni_val_split_single.csv
# AVAILABLE MRI Cohorts:  set()
# NACC MRIs not available
# Avail mris: 0
# 315 are selected for mode 1.
# Out of 107 features in configuration file, [] are unavailable in data file.
# Out of 2 labels in configuration file, 0 are unavailable in data file.
# Total mri embeddings found: {}
# Total mri embeddings found: 0
# Out of 315 samples, 0 are dropped due to complete feature missing.
# Out of 315 samples, 0 are dropped due to complete label missing.

# %%
df = pd.read_csv(data_path)

label_distribution = {}
for label in new_labels:
    label_distribution[label] = dict(df[label].value_counts())
label_fractions = dat_trn.label_fractions

print(label_fractions)
print(label_distribution)

num_epochs = 128
batch_size = 128
lr = 1e-3
weight_decay = 0.01
gamma = 2
fusion_stage = 'middle'
load_from_ckpt = False
save_intermediate_ckpts = True
ranking_loss = True
train_imgnet = False

# initialize Transformer
mdl = ADRDModel(
    src_modalities = dat_trn.feature_modalities,
    tgt_modalities = dat_trn.label_modalities,
    label_fractions = label_fractions,
    d_model = d_model,
    nhead = nhead,
    num_epochs = num_epochs,
    batch_size = batch_size, 
    lr = lr,
    weight_decay = weight_decay,
    gamma = gamma,
    criterion = 'AUC (ROC)',
    device = 'cpu',
    cuda_devices = [1,2],
    img_net = img_net,
    imgnet_layers = imgnet_layers,
    img_size = img_size,
    fusion_stage= fusion_stage,
    imgnet_ckpt = imgnet_ckpt,
    patch_size = patch_size,
    ckpt_path = new_ckpt_path,
    train_imgnet = train_imgnet,
    load_from_ckpt = load_from_ckpt,
    save_intermediate_ckpts = save_intermediate_ckpts,
    data_parallel = False,
    verbose = 4,
    wandb_ = 1,
    label_distribution = label_distribution,
    ranking_loss = ranking_loss,
    _amp_enabled = False,
    _dataloader_num_workers = 1,
)
# Out:
# {'amy_label': 0.49445324881141045, 'tau_label': 0.13391442155309033}
# {'amy_label': {0: 804, 1: 773}, 'tau_label': {0.0: 602, 1.0: 212}}
# Device: cpu

# %%
# Copy the saved model weights to the new model state dictionary
new_mdl_state_dict = mdl.net_.state_dict()
for key in state_dict.keys():
    if key in labels_to_remove or key == 'emb_aux':
        continue
    if key in new_mdl_state_dict:
        new_mdl_state_dict[key] = state_dict[key]

# Load the updated state dictionary into the new model
mdl.net_.load_state_dict(new_mdl_state_dict)
# Out:
# <All keys matched successfully>

# %%
# Train the model
mdl.fit(dat_trn.features, dat_vld.features, dat_trn.labels, dat_vld.labels, img_train_trans=None, img_vld_trans=None, img_mode=img_mode)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: varunaja (pet-proj). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/home/varunaja/mri_pet/adrd_tool_varuna/wandb/run-20240301_114749-n73ci4vj</code>
# Syncing run <strong><a href='https://wandb.ai/pet-proj/ADRD_main/runs/n73ci4vj' target="_blank">radiant-spaceship-24</a></strong> to <a href='https://wandb.ai/pet-proj/ADRD_main' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pet-proj/ADRD_main' target="_blank">https://wandb.ai/pet-proj/ADRD_main</a>
#  View run at <a href='https://wandb.ai/pet-proj/ADRD_main/runs/n73ci4vj' target="_blank">https://wandb.ai/pet-proj/ADRD_main/runs/n73ci4vj</a>
# AUC (ROC)
# Ranking loss: True
# Batch size: 128
# None
# Epoch 000 (TRN): 100%|| 1262/1262 [00:07<00:00, 176.21it/s]
# Accuracy:           0.5689    0.6093
# Balanced Accuracy:  0.5688    0.5483
# Precision:          0.5656    0.3156
# Sensitivity/Recall: 0.5529    0.4201
# Specificity:        0.5846    0.6765
# F1 score:           0.5592    0.3604
# MCC:                0.1376    0.0891
# AUC (ROC):          0.5892    0.5785
# AUC (PR):           0.6021    0.3839
# Loss:               3.4742    0.7240
# Epoch 000 (VLD): 100%|| 315/315 [00:01<00:00, 308.95it/s]
# Accuracy:           0.6762    0.3077
# Balanced Accuracy:  0.6660    0.5357
# Precision:          0.7474    0.2687
# Sensitivity/Recall: 0.4765    1.0000
# Specificity:        0.8554    0.0714
# F1 score:           0.5820    0.4236
# MCC:                0.3611    0.1386
# AUC (ROC):          0.7268    0.8765
# AUC (PR):           0.7300    0.7146
# Loss:               3.0679    0.6457
# model_ckpt_finetune.pt
# Saving the model to ./dev/ckpt/model_ckpt_finetune_AUPR.pt...
# Saving the model to ./dev/ckpt/model_ckpt_finetune.pt...
# Best AUC (ROC): 0.8016679977731613
# Best AUC (PR): 0.7222656119682938
# Epoch 001 (TRN): 100%|| 1262/1262 [00:06<00:00, 185.72it/s]
# Accuracy:           0.6339    0.5426
# Balanced Accuracy:  0.6328    0.6367
# Precision:          0.6601    0.3456
# Sensitivity/Recall: 0.5353    0.8343
# Specificity:        0.7304    0.4391
# F1 score:           0.5912    0.4887
# MCC:                0.2710    0.2494
# AUC (ROC):          0.6779    0.7277
# AUC (PR):           0.6810    0.4937
# Loss:               3.2544    0.6078
# Epoch 001 (VLD): 100%|| 315/315 [00:01<00:00, 297.63it/s]
# Accuracy:           0.6762    0.8462
# Balanced Accuracy:  0.6653    0.7972
# Precision:          0.7582    0.6977
# Sensitivity/Recall: 0.4631    0.6977
# Specificity:        0.8675    0.8968
# F1 score:           0.5750    0.6977
# MCC:                0.3641    0.5945
# AUC (ROC):          0.7369    0.8815
# AUC (PR):           0.7351    0.7186
# Loss:               3.0527    0.5195
# model_ckpt_finetune.pt
# Saving the model to ./dev/ckpt/model_ckpt_finetune_AUPR.pt...
# Saving the model to ./dev/ckpt/model_ckpt_finetune.pt...
# Best AUC (ROC): 0.8092134642608426
# Best AUC (PR): 0.7268470417782322
# Epoch 002 (TRN): 100%|| 1262/1262 [00:06<00:00, 185.96it/s]
# Accuracy:           0.6165    0.7287
# Balanced Accuracy:  0.6157    0.6864
# Precision:          0.6306    0.4856
# Sensitivity/Recall: 0.5417    0.5976
# Specificity:        0.6897    0.7752
# F1 score:           0.5828    0.5358
# MCC:                0.2340    0.3508
# AUC (ROC):          0.6569    0.7527
# AUC (PR):           0.6665    0.5611
# Loss:               3.2948    0.5806
# Epoch 002 (VLD): 100%|| 315/315 [00:01<00:00, 299.71it/s]
# Accuracy:           0.6762    0.8402
# Balanced Accuracy:  0.6660    0.7856
# Precision:          0.7474    0.6905
# Sensitivity/Recall: 0.4765    0.6744
# Specificity:        0.8554    0.8968
# F1 score:           0.5820    0.6824
# MCC:                0.3611    0.5757
# AUC (ROC):          0.7388    0.8828
# AUC (PR):           0.7384    0.7145
# Loss:               3.0732    0.5129
# model_ckpt_finetune.pt
# Saving the model to ./dev/ckpt/model_ckpt_finetune.pt...
# Best AUC (ROC): 0.8107893531658201
# Best AUC (PR): 0.7268470417782322
# Epoch 003 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.77it/s]
# Accuracy:           0.6292    0.7132
# Balanced Accuracy:  0.6279    0.7007
# Precision:          0.6605    0.4672
# Sensitivity/Recall: 0.5144    0.6746
# Specificity:        0.7414    0.7269
# F1 score:           0.5784    0.5521
# MCC:                0.2628    0.3640
# AUC (ROC):          0.6640    0.7641
# AUC (PR):           0.6635    0.5832
# Loss:               3.2881    0.5710
# Epoch 003 (VLD): 100%|| 315/315 [00:01<00:00, 308.48it/s]
# Accuracy:           0.6762    0.7870
# Balanced Accuracy:  0.6694    0.8265
# Precision:          0.7043    0.5493
# Sensitivity/Recall: 0.5436    0.9070
# Specificity:        0.7952    0.7460
# F1 score:           0.6136    0.6842
# MCC:                0.3513    0.5762
# AUC (ROC):          0.7393    0.8907
# AUC (PR):           0.7398    0.7324
# Loss:               3.0548    0.5141
# model_ckpt_finetune.pt
# Saving the model to ./dev/ckpt/model_ckpt_finetune_AUPR.pt...
# Saving the model to ./dev/ckpt/model_ckpt_finetune.pt...
# Best AUC (ROC): 0.8150001881965792
# Best AUC (PR): 0.7361210591813809
# Epoch 004 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.68it/s]
# Accuracy:           0.6474    0.6620
# Balanced Accuracy:  0.6467    0.6909
# Precision:          0.6618    0.4191
# Sensitivity/Recall: 0.5865    0.7515
# Specificity:        0.7069    0.6303
# F1 score:           0.6219    0.5381
# MCC:                0.2957    0.3363
# AUC (ROC):          0.6924    0.7899
# AUC (PR):           0.7054    0.6379
# Loss:               3.1934    0.5460
# Epoch 004 (VLD): 100%|| 315/315 [00:01<00:00, 299.47it/s]
# Accuracy:           0.6921    0.8343
# Balanced Accuracy:  0.6831    0.8276
# Precision:          0.7549    0.6364
# Sensitivity/Recall: 0.5168    0.8140
# Specificity:        0.8494    0.8413
# F1 score:           0.6135    0.7143
# MCC:                0.3907    0.6091
# AUC (ROC):          0.7362    0.8961
# AUC (PR):           0.7349    0.7360
# Loss:               3.0570    0.4543
# model_ckpt_finetune.pt
# Saving the model to ./dev/ckpt/model_ckpt_finetune.pt...
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 005 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.21it/s]
# Accuracy:           0.6458    0.7504
# Balanced Accuracy:  0.6449    0.7278
# Precision:          0.6667    0.5180
# Sensitivity/Recall: 0.5673    0.6805
# Specificity:        0.7226    0.7752
# F1 score:           0.6130    0.5882
# MCC:                0.2936    0.4218
# AUC (ROC):          0.6935    0.8007
# AUC (PR):           0.7017    0.6567
# Loss:               3.2025    0.5358
# Epoch 005 (VLD): 100%|| 315/315 [00:01<00:00, 299.29it/s]
# Accuracy:           0.6730    0.8402
# Balanced Accuracy:  0.6726    0.8163
# Precision:          0.6513    0.6600
# Sensitivity/Recall: 0.6644    0.7674
# Specificity:        0.6807    0.8651
# F1 score:           0.6578    0.7097
# MCC:                0.3449    0.6036
# AUC (ROC):          0.7368    0.8872
# AUC (PR):           0.7404    0.7197
# Loss:               3.0638    0.4776
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 006 (TRN): 100%|| 1262/1262 [00:06<00:00, 180.89it/s]
# Accuracy:           0.6395    0.7566
# Balanced Accuracy:  0.6383    0.7320
# Precision:          0.6700    0.5275
# Sensitivity/Recall: 0.5337    0.6805
# Specificity:        0.7429    0.7836
# F1 score:           0.5941    0.5943
# MCC:                0.2830    0.4314
# AUC (ROC):          0.6766    0.8070
# AUC (PR):           0.6875    0.6235
# Loss:               3.2406    0.5375
# Epoch 006 (VLD): 100%|| 315/315 [00:01<00:00, 306.26it/s]
# Accuracy:           0.6762    0.8521
# Balanced Accuracy:  0.6660    0.8242
# Precision:          0.7474    0.6875
# Sensitivity/Recall: 0.4765    0.7674
# Specificity:        0.8554    0.8810
# F1 score:           0.5820    0.7253
# MCC:                0.3611    0.6262
# AUC (ROC):          0.7324    0.8732
# AUC (PR):           0.7385    0.7120
# Loss:               3.0393    0.4926
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 007 (TRN): 100%|| 1262/1262 [00:07<00:00, 178.71it/s]
# Accuracy:           0.6521    0.7349
# Balanced Accuracy:  0.6512    0.7192
# Precision:          0.6789    0.4957
# Sensitivity/Recall: 0.5625    0.6864
# Specificity:        0.7398    0.7521
# F1 score:           0.6152    0.5757
# MCC:                0.3074    0.4010
# AUC (ROC):          0.6905    0.7907
# AUC (PR):           0.6986    0.6299
# Loss:               3.1878    0.5453
# Epoch 007 (VLD): 100%|| 315/315 [00:01<00:00, 288.45it/s]
# Accuracy:           0.6794    0.7811
# Balanced Accuracy:  0.6724    0.8072
# Precision:          0.7105    0.5441
# Sensitivity/Recall: 0.5436    0.8605
# Specificity:        0.8012    0.7540
# F1 score:           0.6160    0.6667
# MCC:                0.3583    0.5457
# AUC (ROC):          0.7315    0.8666
# AUC (PR):           0.7378    0.6892
# Loss:               3.0384    0.5205
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 008 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.27it/s]
# Accuracy:           0.6458    0.6713
# Balanced Accuracy:  0.6444    0.6857
# Precision:          0.6863    0.4246
# Sensitivity/Recall: 0.5224    0.7160
# Specificity:        0.7665    0.6555
# F1 score:           0.5933    0.5330
# MCC:                0.2981    0.3289
# AUC (ROC):          0.6871    0.7604
# AUC (PR):           0.6928    0.5958
# Loss:               3.1991    0.5783
# Epoch 008 (VLD): 100%|| 315/315 [00:00<00:00, 319.35it/s]
# Accuracy:           0.6794    0.8107
# Balanced Accuracy:  0.6734    0.8194
# Precision:          0.7000    0.5902
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7831    0.8016
# F1 score:           0.6245    0.6923
# MCC:                0.3566    0.5793
# AUC (ROC):          0.7325    0.8697
# AUC (PR):           0.7396    0.7022
# Loss:               3.0310    0.5075
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 009 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.04it/s]
# Accuracy:           0.6648    0.7643
# Balanced Accuracy:  0.6636    0.7278
# Precision:          0.7039    0.5419
# Sensitivity/Recall: 0.5561    0.6509
# Specificity:        0.7712    0.8046
# F1 score:           0.6213    0.5914
# MCC:                0.3353    0.4313
# AUC (ROC):          0.7025    0.7970
# AUC (PR):           0.7156    0.6299
# Loss:               3.1427    0.5418
# Epoch 009 (VLD): 100%|| 315/315 [00:01<00:00, 296.76it/s]
# Accuracy:           0.6921    0.8402
# Balanced Accuracy:  0.6845    0.7933
# Precision:          0.7364    0.6818
# Sensitivity/Recall: 0.5436    0.6977
# Specificity:        0.8253    0.8889
# F1 score:           0.6255    0.6897
# MCC:                0.3864    0.5822
# AUC (ROC):          0.7335    0.8726
# AUC (PR):           0.7399    0.7069
# Loss:               3.0156    0.5007
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 010 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.60it/s]
# Accuracy:           0.6593    0.7814
# Balanced Accuracy:  0.6582    0.7527
# Precision:          0.6909    0.5680
# Sensitivity/Recall: 0.5625    0.6923
# Specificity:        0.7539    0.8130
# F1 score:           0.6201    0.6240
# MCC:                0.3226    0.4766
# AUC (ROC):          0.7039    0.8059
# AUC (PR):           0.7142    0.6521
# Loss:               3.1462    0.5323
# Epoch 010 (VLD): 100%|| 315/315 [00:01<00:00, 300.07it/s]
# Accuracy:           0.6571    0.8225
# Balanced Accuracy:  0.6551    0.8273
# Precision:          0.6434    0.6102
# Sensitivity/Recall: 0.6174    0.8372
# Specificity:        0.6928    0.8175
# F1 score:           0.6301    0.7059
# MCC:                0.3111    0.5982
# AUC (ROC):          0.7340    0.8749
# AUC (PR):           0.7401    0.7042
# Loss:               3.0563    0.4946
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 011 (TRN): 100%|| 1262/1262 [00:06<00:00, 185.71it/s]
# Accuracy:           0.6601    0.7814
# Balanced Accuracy:  0.6593    0.7603
# Precision:          0.6816    0.5654
# Sensitivity/Recall: 0.5865    0.7160
# Specificity:        0.7320    0.8046
# F1 score:           0.6305    0.6319
# MCC:                0.3221    0.4862
# AUC (ROC):          0.7052    0.8028
# AUC (PR):           0.7253    0.6538
# Loss:               3.1280    0.5297
# Epoch 011 (VLD): 100%|| 315/315 [00:01<00:00, 302.16it/s]
# Accuracy:           0.6889    0.8284
# Balanced Accuracy:  0.6780    0.8007
# Precision:          0.7802    0.6400
# Sensitivity/Recall: 0.4765    0.7442
# Specificity:        0.8795    0.8571
# F1 score:           0.5917    0.6882
# MCC:                0.3922    0.5738
# AUC (ROC):          0.7313    0.8721
# AUC (PR):           0.7398    0.6916
# Loss:               3.0422    0.4930
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 012 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.20it/s]
# Accuracy:           0.6616    0.7519
# Balanced Accuracy:  0.6604    0.7155
# Precision:          0.7023    0.5217
# Sensitivity/Recall: 0.5481    0.6391
# Specificity:        0.7727    0.7920
# F1 score:           0.6157    0.5745
# MCC:                0.3295    0.4060
# AUC (ROC):          0.7089    0.7700
# AUC (PR):           0.7243    0.6005
# Loss:               3.1176    0.5671
# Epoch 012 (VLD): 100%|| 315/315 [00:01<00:00, 291.15it/s]
# Accuracy:           0.6730    0.8166
# Balanced Accuracy:  0.6681    0.8234
# Precision:          0.6825    0.6000
# Sensitivity/Recall: 0.5772    0.8372
# Specificity:        0.7590    0.8095
# F1 score:           0.6255    0.6990
# MCC:                0.3427    0.5886
# AUC (ROC):          0.7314    0.8732
# AUC (PR):           0.7411    0.7016
# Loss:               3.0391    0.4902
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 013 (TRN): 100%|| 1262/1262 [00:06<00:00, 185.09it/s]
# Accuracy:           0.6727    0.7690
# Balanced Accuracy:  0.6715    0.7500
# Precision:          0.7140    0.5455
# Sensitivity/Recall: 0.5641    0.7101
# Specificity:        0.7790    0.7899
# F1 score:           0.6303    0.6170
# MCC:                0.3516    0.4638
# AUC (ROC):          0.7161    0.8129
# AUC (PR):           0.7229    0.6232
# Loss:               3.1124    0.5306
# Epoch 013 (VLD): 100%|| 315/315 [00:01<00:00, 292.21it/s]
# Accuracy:           0.6857    0.8462
# Balanced Accuracy:  0.6753    0.8355
# Precision:          0.7660    0.6604
# Sensitivity/Recall: 0.4832    0.8140
# Specificity:        0.8675    0.8571
# F1 score:           0.5926    0.7292
# MCC:                0.3827    0.6300
# AUC (ROC):          0.7307    0.8721
# AUC (PR):           0.7354    0.6816
# Loss:               3.0321    0.4985
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 014 (TRN): 100%|| 1262/1262 [00:06<00:00, 185.28it/s]
# Accuracy:           0.6609    0.7628
# Balanced Accuracy:  0.6601    0.7248
# Precision:          0.6808    0.5396
# Sensitivity/Recall: 0.5913    0.6450
# Specificity:        0.7288    0.8046
# F1 score:           0.6329    0.5876
# MCC:                0.3234    0.4263
# AUC (ROC):          0.7084    0.8033
# AUC (PR):           0.7209    0.6147
# Loss:               3.1335    0.5386
# Epoch 014 (VLD): 100%|| 315/315 [00:01<00:00, 301.90it/s]
# Accuracy:           0.6857    0.8462
# Balanced Accuracy:  0.6788    0.8432
# Precision:          0.7193    0.6545
# Sensitivity/Recall: 0.5503    0.8372
# Specificity:        0.8072    0.8492
# F1 score:           0.6236    0.7347
# MCC:                0.3715    0.6381
# AUC (ROC):          0.7316    0.8734
# AUC (PR):           0.7325    0.6722
# Loss:               3.0318    0.4903
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 015 (TRN): 100%|| 1262/1262 [00:07<00:00, 179.70it/s]
# Accuracy:           0.6529    0.7705
# Balanced Accuracy:  0.6516    0.7320
# Precision:          0.6954    0.5528
# Sensitivity/Recall: 0.5304    0.6509
# Specificity:        0.7727    0.8130
# F1 score:           0.6018    0.5978
# MCC:                0.3127    0.4417
# AUC (ROC):          0.6978    0.7925
# AUC (PR):           0.6985    0.6027
# Loss:               3.1796    0.5610
# Epoch 015 (VLD): 100%|| 315/315 [00:01<00:00, 300.33it/s]
# Accuracy:           0.6698    0.8343
# Balanced Accuracy:  0.6651    0.8353
# Precision:          0.6772    0.6316
# Sensitivity/Recall: 0.5772    0.8372
# Specificity:        0.7530    0.8333
# F1 score:           0.6232    0.7200
# MCC:                0.3361    0.6177
# AUC (ROC):          0.7319    0.8723
# AUC (PR):           0.7355    0.6707
# Loss:               3.0371    0.4966
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 016 (TRN): 100%|| 1262/1262 [00:06<00:00, 184.03it/s]
# Accuracy:           0.6632    0.7380
# Balanced Accuracy:  0.6626    0.7156
# Precision:          0.6774    0.5000
# Sensitivity/Recall: 0.6090    0.6686
# Specificity:        0.7163    0.7626
# F1 score:           0.6414    0.5722
# MCC:                0.3273    0.3975
# AUC (ROC):          0.7141    0.8045
# AUC (PR):           0.7155    0.6469
# Loss:               3.1360    0.5277
# Epoch 016 (VLD): 100%|| 315/315 [00:01<00:00, 288.54it/s]
# Accuracy:           0.6698    0.8402
# Balanced Accuracy:  0.6644    0.8392
# Precision:          0.6829    0.6429
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7651    0.8413
# F1 score:           0.6176    0.7273
# MCC:                0.3365    0.6278
# AUC (ROC):          0.7323    0.8741
# AUC (PR):           0.7368    0.6896
# Loss:               3.0301    0.4999
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 017 (TRN): 100%|| 1262/1262 [00:06<00:00, 186.64it/s]
# Accuracy:           0.6743    0.7690
# Balanced Accuracy:  0.6730    0.7519
# Precision:          0.7214    0.5450
# Sensitivity/Recall: 0.5561    0.7160
# Specificity:        0.7900    0.7878
# F1 score:           0.6281    0.6189
# MCC:                0.3562    0.4663
# AUC (ROC):          0.7276    0.8032
# AUC (PR):           0.7233    0.6489
# Loss:               3.0943    0.5355
# Epoch 017 (VLD): 100%|| 315/315 [00:01<00:00, 309.45it/s]
# Accuracy:           0.6667    0.8166
# Balanced Accuracy:  0.6614    0.8234
# Precision:          0.6774    0.6000
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7590    0.8095
# F1 score:           0.6154    0.6990
# MCC:                0.3299    0.5886
# AUC (ROC):          0.7324    0.8763
# AUC (PR):           0.7385    0.6949
# Loss:               3.0280    0.4900
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 018 (TRN): 100%|| 1262/1262 [00:07<00:00, 179.27it/s]
# Accuracy:           0.6664    0.7240
# Balanced Accuracy:  0.6655    0.7138
# Precision:          0.6926    0.4815
# Sensitivity/Recall: 0.5849    0.6923
# Specificity:        0.7461    0.7353
# F1 score:           0.6342    0.5680
# MCC:                0.3356    0.3880
# AUC (ROC):          0.7186    0.8063
# AUC (PR):           0.7367    0.6577
# Loss:               3.0860    0.5293
# Epoch 018 (VLD): 100%|| 315/315 [00:01<00:00, 288.21it/s]
# Accuracy:           0.6635    0.8462
# Balanced Accuracy:  0.6577    0.8432
# Precision:          0.6777    0.6545
# Sensitivity/Recall: 0.5503    0.8372
# Specificity:        0.7651    0.8492
# F1 score:           0.6074    0.7347
# MCC:                0.3237    0.6381
# AUC (ROC):          0.7324    0.8684
# AUC (PR):           0.7381    0.6740
# Loss:               3.0270    0.4874
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 019 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.70it/s]
# Accuracy:           0.6688    0.7984
# Balanced Accuracy:  0.6676    0.7604
# Precision:          0.7093    0.6021
# Sensitivity/Recall: 0.5593    0.6805
# Specificity:        0.7759    0.8403
# F1 score:           0.6254    0.6389
# MCC:                0.3436    0.5016
# AUC (ROC):          0.7112    0.8244
# AUC (PR):           0.7268    0.6749
# Loss:               3.1214    0.5151
# Epoch 019 (VLD): 100%|| 315/315 [00:01<00:00, 296.95it/s]
# Accuracy:           0.6667    0.8462
# Balanced Accuracy:  0.6638    0.8279
# Precision:          0.6594    0.6667
# Sensitivity/Recall: 0.6107    0.7907
# Specificity:        0.7169    0.8651
# F1 score:           0.6341    0.7234
# MCC:                0.3297    0.6222
# AUC (ROC):          0.7288    0.8671
# AUC (PR):           0.7354    0.6771
# Loss:               3.0506    0.4941
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 020 (TRN): 100%|| 1262/1262 [00:07<00:00, 173.50it/s]
# Accuracy:           0.6672    0.7597
# Balanced Accuracy:  0.6665    0.7322
# Precision:          0.6848    0.5327
# Sensitivity/Recall: 0.6058    0.6746
# Specificity:        0.7273    0.7899
# F1 score:           0.6429    0.5953
# MCC:                0.3357    0.4338
# AUC (ROC):          0.7162    0.8005
# AUC (PR):           0.7357    0.6384
# Loss:               3.0855    0.5373
# Epoch 020 (VLD): 100%|| 315/315 [00:01<00:00, 289.63it/s]
# Accuracy:           0.6698    0.8047
# Balanced Accuracy:  0.6641    0.8154
# Precision:          0.6860    0.5806
# Sensitivity/Recall: 0.5570    0.8372
# Specificity:        0.7711    0.7937
# F1 score:           0.6148    0.6857
# MCC:                0.3368    0.5701
# AUC (ROC):          0.7362    0.8762
# AUC (PR):           0.7396    0.6993
# Loss:               3.0339    0.4908
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 021 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.95it/s]
# Accuracy:           0.6640    0.7659
# Balanced Accuracy:  0.6627    0.7383
# Precision:          0.7092    0.5425
# Sensitivity/Recall: 0.5433    0.6805
# Specificity:        0.7821    0.7962
# F1 score:           0.6152    0.6037
# MCC:                0.3354    0.4462
# AUC (ROC):          0.7115    0.8163
# AUC (PR):           0.7284    0.6501
# Loss:               3.1216    0.5248
# Epoch 021 (VLD): 100%|| 315/315 [00:01<00:00, 293.24it/s]
# Accuracy:           0.6667    0.8402
# Balanced Accuracy:  0.6624    0.8392
# Precision:          0.6692    0.6429
# Sensitivity/Recall: 0.5839    0.8372
# Specificity:        0.7410    0.8413
# F1 score:           0.6237    0.7273
# MCC:                0.3294    0.6278
# AUC (ROC):          0.7359    0.8728
# AUC (PR):           0.7384    0.6983
# Loss:               3.0343    0.4877
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 022 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.03it/s]
# Accuracy:           0.6783    0.7705
# Balanced Accuracy:  0.6773    0.7415
# Precision:          0.7104    0.5502
# Sensitivity/Recall: 0.5897    0.6805
# Specificity:        0.7649    0.8025
# F1 score:           0.6445    0.6085
# MCC:                0.3604    0.4538
# AUC (ROC):          0.7188    0.8061
# AUC (PR):           0.7209    0.6322
# Loss:               3.1182    0.5346
# Epoch 022 (VLD): 100%|| 315/315 [00:01<00:00, 294.01it/s]
# Accuracy:           0.6698    0.7988
# Balanced Accuracy:  0.6644    0.8115
# Precision:          0.6829    0.5714
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7651    0.7857
# F1 score:           0.6176    0.6792
# MCC:                0.3365    0.5611
# AUC (ROC):          0.7351    0.8726
# AUC (PR):           0.7396    0.7008
# Loss:               3.0219    0.4940
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 023 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.18it/s]
# Accuracy:           0.6648    0.7659
# Balanced Accuracy:  0.6636    0.7612
# Precision:          0.7072    0.5381
# Sensitivity/Recall: 0.5497    0.7515
# Specificity:        0.7774    0.7710
# F1 score:           0.6186    0.6272
# MCC:                0.3362    0.4770
# AUC (ROC):          0.7222    0.8233
# AUC (PR):           0.7261    0.6749
# Loss:               3.0923    0.5155
# Epoch 023 (VLD): 100%|| 315/315 [00:01<00:00, 294.15it/s]
# Accuracy:           0.6667    0.8284
# Balanced Accuracy:  0.6611    0.8313
# Precision:          0.6803    0.6207
# Sensitivity/Recall: 0.5570    0.8372
# Specificity:        0.7651    0.8254
# F1 score:           0.6125    0.7129
# MCC:                0.3301    0.6079
# AUC (ROC):          0.7316    0.8645
# AUC (PR):           0.7377    0.6883
# Loss:               3.0437    0.4884
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 024 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.07it/s]
# Accuracy:           0.6854    0.8016
# Balanced Accuracy:  0.6845    0.7625
# Precision:          0.7170    0.6085
# Sensitivity/Recall: 0.6010    0.6805
# Specificity:        0.7680    0.8445
# F1 score:           0.6539    0.6425
# MCC:                0.3745    0.5072
# AUC (ROC):          0.7233    0.8266
# AUC (PR):           0.7270    0.6613
# Loss:               3.0894    0.5126
# Epoch 024 (VLD): 100%|| 315/315 [00:01<00:00, 296.50it/s]
# Accuracy:           0.6730    0.8402
# Balanced Accuracy:  0.6678    0.8316
# Precision:          0.6855    0.6481
# Sensitivity/Recall: 0.5705    0.8140
# Specificity:        0.7651    0.8492
# F1 score:           0.6227    0.7216
# MCC:                0.3429    0.6194
# AUC (ROC):          0.7315    0.8601
# AUC (PR):           0.7346    0.6776
# Loss:               3.0590    0.4999
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 025 (TRN): 100%|| 1262/1262 [00:06<00:00, 186.28it/s]
# Accuracy:           0.6712    0.7767
# Balanced Accuracy:  0.6701    0.7381
# Precision:          0.7069    0.5635
# Sensitivity/Recall: 0.5721    0.6568
# Specificity:        0.7680    0.8193
# F1 score:           0.6324    0.6066
# MCC:                0.3471    0.4546
# AUC (ROC):          0.7021    0.7988
# AUC (PR):           0.7176    0.6495
# Loss:               3.1450    0.5406
# Epoch 025 (VLD): 100%|| 315/315 [00:01<00:00, 305.02it/s]
# Accuracy:           0.6667    0.8107
# Balanced Accuracy:  0.6638    0.8347
# Precision:          0.6594    0.5846
# Sensitivity/Recall: 0.6107    0.8837
# Specificity:        0.7169    0.7857
# F1 score:           0.6341    0.7037
# MCC:                0.3297    0.5993
# AUC (ROC):          0.7296    0.8636
# AUC (PR):           0.7315    0.6773
# Loss:               3.0598    0.5191
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 026 (TRN): 100%|| 1262/1262 [00:07<00:00, 179.70it/s]
# Accuracy:           0.6577    0.7364
# Balanced Accuracy:  0.6566    0.7375
# Precision:          0.6905    0.4980
# Sensitivity/Recall: 0.5577    0.7396
# Specificity:        0.7555    0.7353
# F1 score:           0.6170    0.5952
# MCC:                0.3197    0.4284
# AUC (ROC):          0.7074    0.8250
# AUC (PR):           0.7096    0.6719
# Loss:               3.1412    0.5195
# Epoch 026 (VLD): 100%|| 315/315 [00:01<00:00, 285.47it/s]
# Accuracy:           0.6730    0.8107
# Balanced Accuracy:  0.6671    0.8194
# Precision:          0.6917    0.5902
# Sensitivity/Recall: 0.5570    0.8372
# Specificity:        0.7771    0.8016
# F1 score:           0.6171    0.6923
# MCC:                0.3435    0.5793
# AUC (ROC):          0.7331    0.8684
# AUC (PR):           0.7363    0.6843
# Loss:               3.0282    0.4973
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 027 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.79it/s]
# Accuracy:           0.6688    0.7767
# Balanced Accuracy:  0.6679    0.7438
# Precision:          0.6966    0.5616
# Sensitivity/Recall: 0.5849    0.6746
# Specificity:        0.7508    0.8130
# F1 score:           0.6359    0.6129
# MCC:                0.3406    0.4617
# AUC (ROC):          0.7184    0.8134
# AUC (PR):           0.7278    0.6801
# Loss:               3.0908    0.5183
# Epoch 027 (VLD): 100%|| 315/315 [00:01<00:00, 296.45it/s]
# Accuracy:           0.6635    0.8521
# Balanced Accuracy:  0.6594    0.8472
# Precision:          0.6641    0.6667
# Sensitivity/Recall: 0.5839    0.8372
# Specificity:        0.7349    0.8571
# F1 score:           0.6214    0.7423
# MCC:                0.3230    0.6486
# AUC (ROC):          0.7333    0.8678
# AUC (PR):           0.7368    0.6826
# Loss:               3.0425    0.4925
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 028 (TRN): 100%|| 1262/1262 [00:06<00:00, 180.33it/s]
# Accuracy:           0.6585    0.7814
# Balanced Accuracy:  0.6573    0.7489
# Precision:          0.6949    0.5693
# Sensitivity/Recall: 0.5513    0.6805
# Specificity:        0.7633    0.8172
# F1 score:           0.6148    0.6199
# MCC:                0.3222    0.4719
# AUC (ROC):          0.7082    0.8146
# AUC (PR):           0.7074    0.6617
# Loss:               3.1477    0.5204
# Epoch 028 (VLD): 100%|| 315/315 [00:01<00:00, 288.35it/s]
# Accuracy:           0.6730    0.8225
# Balanced Accuracy:  0.6678    0.8273
# Precision:          0.6855    0.6102
# Sensitivity/Recall: 0.5705    0.8372
# Specificity:        0.7651    0.8175
# F1 score:           0.6227    0.7059
# MCC:                0.3429    0.5982
# AUC (ROC):          0.7342    0.8669
# AUC (PR):           0.7381    0.6813
# Loss:               3.0364    0.4973
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 029 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.88it/s]
# Accuracy:           0.6743    0.8000
# Balanced Accuracy:  0.6731    0.7672
# Precision:          0.7160    0.6020
# Sensitivity/Recall: 0.5657    0.6982
# Specificity:        0.7806    0.8361
# F1 score:           0.6321    0.6466
# MCC:                0.3548    0.5109
# AUC (ROC):          0.7336    0.8265
# AUC (PR):           0.7349    0.6602
# Loss:               3.0609    0.5142
# Epoch 029 (VLD): 100%|| 315/315 [00:01<00:00, 299.57it/s]
# Accuracy:           0.6635    0.8284
# Balanced Accuracy:  0.6577    0.8313
# Precision:          0.6777    0.6207
# Sensitivity/Recall: 0.5503    0.8372
# Specificity:        0.7651    0.8254
# F1 score:           0.6074    0.7129
# MCC:                0.3237    0.6079
# AUC (ROC):          0.7329    0.8675
# AUC (PR):           0.7364    0.6807
# Loss:               3.0283    0.4992
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 030 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.60it/s]
# Accuracy:           0.6624    0.7690
# Balanced Accuracy:  0.6615    0.7462
# Precision:          0.6889    0.5463
# Sensitivity/Recall: 0.5785    0.6982
# Specificity:        0.7445    0.7941
# F1 score:           0.6289    0.6130
# MCC:                0.3278    0.4587
# AUC (ROC):          0.7224    0.8078
# AUC (PR):           0.7262    0.6387
# Loss:               3.0949    0.5344
# Epoch 030 (VLD): 100%|| 315/315 [00:01<00:00, 282.56it/s]
# Accuracy:           0.6603    0.8107
# Balanced Accuracy:  0.6561    0.8194
# Precision:          0.6615    0.5902
# Sensitivity/Recall: 0.5772    0.8372
# Specificity:        0.7349    0.8016
# F1 score:           0.6165    0.6923
# MCC:                0.3165    0.5793
# AUC (ROC):          0.7358    0.8725
# AUC (PR):           0.7385    0.6881
# Loss:               3.0248    0.4948
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 031 (TRN): 100%|| 1262/1262 [00:06<00:00, 180.67it/s]
# Accuracy:           0.6830    0.7891
# Balanced Accuracy:  0.6818    0.7579
# Precision:          0.7324    0.5821
# Sensitivity/Recall: 0.5657    0.6923
# Specificity:        0.7978    0.8235
# F1 score:           0.6383    0.6324
# MCC:                0.3741    0.4897
# AUC (ROC):          0.7361    0.8159
# AUC (PR):           0.7490    0.6963
# Loss:               3.0210    0.5123
# Epoch 031 (VLD): 100%|| 315/315 [00:01<00:00, 304.48it/s]
# Accuracy:           0.6667    0.8284
# Balanced Accuracy:  0.6617    0.8313
# Precision:          0.6746    0.6207
# Sensitivity/Recall: 0.5705    0.8372
# Specificity:        0.7530    0.8254
# F1 score:           0.6182    0.7129
# MCC:                0.3297    0.6079
# AUC (ROC):          0.7360    0.8780
# AUC (PR):           0.7411    0.7032
# Loss:               3.0428    0.4775
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 032 (TRN): 100%|| 1262/1262 [00:07<00:00, 179.68it/s]
# Accuracy:           0.6807    0.7550
# Balanced Accuracy:  0.6800    0.7348
# Precision:          0.7005    0.5247
# Sensitivity/Recall: 0.6186    0.6923
# Specificity:        0.7414    0.7773
# F1 score:           0.6570    0.5969
# MCC:                0.3629    0.4342
# AUC (ROC):          0.7261    0.8010
# AUC (PR):           0.7368    0.6213
# Loss:               3.0819    0.5452
# Epoch 032 (VLD): 100%|| 315/315 [00:01<00:00, 305.41it/s]
# Accuracy:           0.6667    0.8343
# Balanced Accuracy:  0.6628    0.8353
# Precision:          0.6667    0.6316
# Sensitivity/Recall: 0.5906    0.8372
# Specificity:        0.7349    0.8333
# F1 score:           0.6263    0.7200
# MCC:                0.3294    0.6177
# AUC (ROC):          0.7343    0.8765
# AUC (PR):           0.7401    0.6954
# Loss:               3.0554    0.4818
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 033 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.95it/s]
# Accuracy:           0.6838    0.7829
# Balanced Accuracy:  0.6828    0.7556
# Precision:          0.7210    0.5700
# Sensitivity/Recall: 0.5881    0.6982
# Specificity:        0.7774    0.8130
# F1 score:           0.6478    0.6277
# MCC:                0.3726    0.4816
# AUC (ROC):          0.7417    0.8133
# AUC (PR):           0.7476    0.6315
# Loss:               3.0310    0.5327
# Epoch 033 (VLD): 100%|| 315/315 [00:01<00:00, 298.33it/s]
# Accuracy:           0.6571    0.8462
# Balanced Accuracy:  0.6510    0.8432
# Precision:          0.6723    0.6545
# Sensitivity/Recall: 0.5369    0.8372
# Specificity:        0.7651    0.8492
# F1 score:           0.5970    0.7347
# MCC:                0.3110    0.6381
# AUC (ROC):          0.7304    0.8749
# AUC (PR):           0.7354    0.6875
# Loss:               3.0360    0.4860
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 034 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.38it/s]
# Accuracy:           0.6545    0.7581
# Balanced Accuracy:  0.6536    0.7178
# Precision:          0.6801    0.5323
# Sensitivity/Recall: 0.5689    0.6331
# Specificity:        0.7382    0.8025
# F1 score:           0.6195    0.5784
# MCC:                0.3118    0.4136
# AUC (ROC):          0.7144    0.7950
# AUC (PR):           0.7282    0.6344
# Loss:               3.0999    0.5401
# Epoch 034 (VLD): 100%|| 315/315 [00:01<00:00, 282.84it/s]
# Accuracy:           0.6540    0.8166
# Balanced Accuracy:  0.6531    0.8234
# Precision:          0.6333    0.6000
# Sensitivity/Recall: 0.6376    0.8372
# Specificity:        0.6687    0.8095
# F1 score:           0.6355    0.6990
# MCC:                0.3062    0.5886
# AUC (ROC):          0.7290    0.8726
# AUC (PR):           0.7353    0.6878
# Loss:               3.0668    0.4964
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 035 (TRN): 100%|| 1262/1262 [00:07<00:00, 180.02it/s]
# Accuracy:           0.6569    0.7814
# Balanced Accuracy:  0.6561    0.7527
# Precision:          0.6778    0.5680
# Sensitivity/Recall: 0.5833    0.6923
# Specificity:        0.7288    0.8130
# F1 score:           0.6270    0.6240
# MCC:                0.3157    0.4766
# AUC (ROC):          0.7160    0.8423
# AUC (PR):           0.7185    0.6741
# Loss:               3.1197    0.4997
# Epoch 035 (VLD): 100%|| 315/315 [00:01<00:00, 293.68it/s]
# Accuracy:           0.6571    0.8521
# Balanced Accuracy:  0.6510    0.8472
# Precision:          0.6723    0.6667
# Sensitivity/Recall: 0.5369    0.8372
# Specificity:        0.7651    0.8571
# F1 score:           0.5970    0.7423
# MCC:                0.3110    0.6486
# AUC (ROC):          0.7301    0.8704
# AUC (PR):           0.7346    0.6829
# Loss:               3.0343    0.4910
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 036 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.64it/s]
# Accuracy:           0.6680    0.7984
# Balanced Accuracy:  0.6667    0.7547
# Precision:          0.7122    0.6054
# Sensitivity/Recall: 0.5513    0.6627
# Specificity:        0.7821    0.8466
# F1 score:           0.6215    0.6328
# MCC:                0.3430    0.4952
# AUC (ROC):          0.7305    0.8112
# AUC (PR):           0.7374    0.6765
# Loss:               3.0526    0.5228
# Epoch 036 (VLD): 100%|| 315/315 [00:01<00:00, 307.35it/s]
# Accuracy:           0.6571    0.8343
# Balanced Accuracy:  0.6544    0.8353
# Precision:          0.6475    0.6316
# Sensitivity/Recall: 0.6040    0.8372
# Specificity:        0.7048    0.8333
# F1 score:           0.6250    0.7200
# MCC:                0.3105    0.6177
# AUC (ROC):          0.7279    0.8702
# AUC (PR):           0.7335    0.6860
# Loss:               3.0617    0.4973
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 037 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.49it/s]
# Accuracy:           0.6656    0.7829
# Balanced Accuracy:  0.6647    0.7518
# Precision:          0.6906    0.5714
# Sensitivity/Recall: 0.5865    0.6864
# Specificity:        0.7429    0.8172
# F1 score:           0.6343    0.6237
# MCC:                0.3338    0.4769
# AUC (ROC):          0.7219    0.8287
# AUC (PR):           0.7191    0.6565
# Loss:               3.1007    0.5140
# Epoch 037 (VLD): 100%|| 315/315 [00:01<00:00, 294.68it/s]
# Accuracy:           0.6540    0.8166
# Balanced Accuracy:  0.6504    0.8234
# Precision:          0.6493    0.6000
# Sensitivity/Recall: 0.5839    0.8372
# Specificity:        0.7169    0.8095
# F1 score:           0.6148    0.6990
# MCC:                0.3037    0.5886
# AUC (ROC):          0.7298    0.8682
# AUC (PR):           0.7373    0.6878
# Loss:               3.0629    0.5038
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 038 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.97it/s]
# Accuracy:           0.6846    0.7581
# Balanced Accuracy:  0.6834    0.7388
# Precision:          0.7335    0.5291
# Sensitivity/Recall: 0.5689    0.6982
# Specificity:        0.7978    0.7794
# F1 score:           0.6408    0.6020
# MCC:                0.3771    0.4416
# AUC (ROC):          0.7303    0.8060
# AUC (PR):           0.7408    0.6355
# Loss:               3.0587    0.5309
# Epoch 038 (VLD): 100%|| 315/315 [00:01<00:00, 292.89it/s]
# Accuracy:           0.6635    0.8166
# Balanced Accuracy:  0.6577    0.8234
# Precision:          0.6777    0.6000
# Sensitivity/Recall: 0.5503    0.8372
# Specificity:        0.7651    0.8095
# F1 score:           0.6074    0.6990
# MCC:                0.3237    0.5886
# AUC (ROC):          0.7305    0.8678
# AUC (PR):           0.7358    0.6900
# Loss:               3.0547    0.4986
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 039 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.83it/s]
# Accuracy:           0.6727    0.7829
# Balanced Accuracy:  0.6716    0.7499
# Precision:          0.7097    0.5721
# Sensitivity/Recall: 0.5721    0.6805
# Specificity:        0.7712    0.8193
# F1 score:           0.6335    0.6216
# MCC:                0.3505    0.4745
# AUC (ROC):          0.7118    0.8132
# AUC (PR):           0.7426    0.6722
# Loss:               3.0814    0.5206
# Epoch 039 (VLD): 100%|| 315/315 [00:01<00:00, 293.54it/s]
# Accuracy:           0.6667    0.8166
# Balanced Accuracy:  0.6655    0.8234
# Precision:          0.6486    0.6000
# Sensitivity/Recall: 0.6443    0.8372
# Specificity:        0.6867    0.8095
# F1 score:           0.6465    0.6990
# MCC:                0.3312    0.5886
# AUC (ROC):          0.7283    0.8675
# AUC (PR):           0.7330    0.6890
# Loss:               3.0985    0.5063
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 040 (TRN): 100%|| 1262/1262 [00:06<00:00, 180.96it/s]
# Accuracy:           0.6775    0.7829
# Balanced Accuracy:  0.6768    0.7499
# Precision:          0.6976    0.5721
# Sensitivity/Recall: 0.6138    0.6805
# Specificity:        0.7398    0.8193
# F1 score:           0.6530    0.6216
# MCC:                0.3566    0.4745
# AUC (ROC):          0.7265    0.8105
# AUC (PR):           0.7322    0.6784
# Loss:               3.0844    0.5153
# Epoch 040 (VLD): 100%|| 315/315 [00:01<00:00, 289.42it/s]
# Accuracy:           0.6444    0.8166
# Balanced Accuracy:  0.6403    0.8234
# Precision:          0.6412    0.6000
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7169    0.8095
# F1 score:           0.6000    0.6990
# MCC:                0.2843    0.5886
# AUC (ROC):          0.7288    0.8695
# AUC (PR):           0.7321    0.6889
# Loss:               3.0632    0.5020
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 041 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.70it/s]
# Accuracy:           0.6735    0.7891
# Balanced Accuracy:  0.6721    0.7503
# Precision:          0.7265    0.5855
# Sensitivity/Recall: 0.5449    0.6686
# Specificity:        0.7994    0.8319
# F1 score:           0.6227    0.6243
# MCC:                0.3563    0.4807
# AUC (ROC):          0.7223    0.8224
# AUC (PR):           0.7272    0.6416
# Loss:               3.0805    0.5201
# Epoch 041 (VLD): 100%|| 315/315 [00:01<00:00, 284.49it/s]
# Accuracy:           0.6476    0.8166
# Balanced Accuracy:  0.6437    0.8234
# Precision:          0.6439    0.6000
# Sensitivity/Recall: 0.5705    0.8372
# Specificity:        0.7169    0.8095
# F1 score:           0.6050    0.6990
# MCC:                0.2908    0.5886
# AUC (ROC):          0.7291    0.8699
# AUC (PR):           0.7340    0.6913
# Loss:               3.0599    0.5009
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 042 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.50it/s]
# Accuracy:           0.6759    0.7767
# Balanced Accuracy:  0.6749    0.7266
# Precision:          0.7079    0.5676
# Sensitivity/Recall: 0.5865    0.6213
# Specificity:        0.7633    0.8319
# F1 score:           0.6415    0.5932
# MCC:                0.3557    0.4407
# AUC (ROC):          0.7243    0.8095
# AUC (PR):           0.7355    0.6412
# Loss:               3.0692    0.5282
# Epoch 042 (VLD): 100%|| 315/315 [00:01<00:00, 284.60it/s]
# Accuracy:           0.6571    0.8107
# Balanced Accuracy:  0.6544    0.8194
# Precision:          0.6475    0.5902
# Sensitivity/Recall: 0.6040    0.8372
# Specificity:        0.7048    0.8016
# F1 score:           0.6250    0.6923
# MCC:                0.3105    0.5793
# AUC (ROC):          0.7291    0.8690
# AUC (PR):           0.7336    0.6926
# Loss:               3.0678    0.5011
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 043 (TRN): 100%|| 1262/1262 [00:06<00:00, 184.32it/s]
# Accuracy:           0.6830    0.7566
# Balanced Accuracy:  0.6820    0.7263
# Precision:          0.7179    0.5283
# Sensitivity/Recall: 0.5913    0.6627
# Specificity:        0.7727    0.7899
# F1 score:           0.6485    0.5879
# MCC:                0.3705    0.4237
# AUC (ROC):          0.7368    0.8102
# AUC (PR):           0.7448    0.6940
# Loss:               3.0464    0.5131
# Epoch 043 (VLD): 100%|| 315/315 [00:01<00:00, 305.38it/s]
# Accuracy:           0.6444    0.8166
# Balanced Accuracy:  0.6403    0.8234
# Precision:          0.6412    0.6000
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7169    0.8095
# F1 score:           0.6000    0.6990
# MCC:                0.2843    0.5886
# AUC (ROC):          0.7282    0.8693
# AUC (PR):           0.7329    0.6911
# Loss:               3.0540    0.4988
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 044 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.05it/s]
# Accuracy:           0.6830    0.7860
# Balanced Accuracy:  0.6818    0.7539
# Precision:          0.7295    0.5771
# Sensitivity/Recall: 0.5705    0.6864
# Specificity:        0.7931    0.8214
# F1 score:           0.6403    0.6270
# MCC:                0.3733    0.4821
# AUC (ROC):          0.7338    0.8195
# AUC (PR):           0.7470    0.6709
# Loss:               3.0291    0.5124
# Epoch 044 (VLD): 100%|| 315/315 [00:01<00:00, 286.13it/s]
# Accuracy:           0.6444    0.8166
# Balanced Accuracy:  0.6413    0.8234
# Precision:          0.6350    0.6000
# Sensitivity/Recall: 0.5839    0.8372
# Specificity:        0.6988    0.8095
# F1 score:           0.6084    0.6990
# MCC:                0.2847    0.5886
# AUC (ROC):          0.7278    0.8666
# AUC (PR):           0.7340    0.6839
# Loss:               3.0753    0.5039
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7361210591813809
# Epoch 045 (TRN): 100%|| 1262/1262 [00:07<00:00, 170.71it/s]
# Accuracy:           0.6759    0.7922
# Balanced Accuracy:  0.6748    0.7543
# Precision:          0.7120    0.5907
# ...
# Sensitivity/Recall: 0.6309    0.8372
# Specificity:        0.7108    0.8095
# F1 score:           0.6460    0.6990
# MCC:                0.3429    0.5886
# AUC (ROC):          0.7305    0.8771
# AUC (PR):           0.7460    0.7341
# Loss:               3.0851    0.4817
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 114 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.67it/s]
# Accuracy:           0.6727    0.7907
# Balanced Accuracy:  0.6720    0.7704
# Precision:          0.6929    0.5802
# Sensitivity/Recall: 0.6074    0.7278
# Specificity:        0.7367    0.8130
# F1 score:           0.6473    0.6457
# MCC:                0.3471    0.5063
# AUC (ROC):          0.7333    0.8492
# AUC (PR):           0.7447    0.6946
# Loss:               3.0471    0.4854
# Epoch 114 (VLD): 100%|| 315/315 [00:01<00:00, 294.81it/s]
# Accuracy:           0.6508    0.8402
# Balanced Accuracy:  0.6463    0.8316
# Precision:          0.6512    0.6481
# Sensitivity/Recall: 0.5638    0.8140
# Specificity:        0.7289    0.8492
# F1 score:           0.6043    0.7216
# MCC:                0.2972    0.6194
# AUC (ROC):          0.7316    0.8786
# AUC (PR):           0.7468    0.7299
# Loss:               3.0391    0.4782
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 115 (TRN): 100%|| 1262/1262 [00:06<00:00, 184.39it/s]
# Accuracy:           0.6672    0.8264
# Balanced Accuracy:  0.6659    0.7850
# Precision:          0.7099    0.6592
# Sensitivity/Recall: 0.5529    0.6982
# Specificity:        0.7790    0.8718
# F1 score:           0.6216    0.6782
# MCC:                0.3410    0.5598
# AUC (ROC):          0.7386    0.8631
# AUC (PR):           0.7594    0.7238
# Loss:               3.0062    0.4671
# Epoch 115 (VLD): 100%|| 315/315 [00:01<00:00, 283.74it/s]
# Accuracy:           0.6667    0.8225
# Balanced Accuracy:  0.6648    0.8197
# Precision:          0.6528    0.6140
# Sensitivity/Recall: 0.6309    0.8140
# Specificity:        0.6988    0.8254
# F1 score:           0.6416    0.7000
# MCC:                0.3304    0.5890
# AUC (ROC):          0.7292    0.8750
# AUC (PR):           0.7444    0.7239
# Loss:               3.0550    0.4849
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 116 (TRN): 100%|| 1262/1262 [00:06<00:00, 187.62it/s]
# Accuracy:           0.6751    0.7798
# Balanced Accuracy:  0.6744    0.7535
# Precision:          0.6974    0.5646
# Sensitivity/Recall: 0.6058    0.6982
# Specificity:        0.7429    0.8088
# F1 score:           0.6484    0.6243
# MCC:                0.3522    0.4764
# AUC (ROC):          0.7432    0.8413
# AUC (PR):           0.7510    0.7097
# Loss:               3.0151    0.4916
# Epoch 116 (VLD): 100%|| 315/315 [00:01<00:00, 291.99it/s]
# Accuracy:           0.6667    0.8284
# Balanced Accuracy:  0.6631    0.8236
# Precision:          0.6642    0.6250
# Sensitivity/Recall: 0.5973    0.8140
# Specificity:        0.7289    0.8333
# F1 score:           0.6290    0.7071
# MCC:                0.3294    0.5989
# AUC (ROC):          0.7284    0.8800
# AUC (PR):           0.7429    0.7287
# Loss:               3.0586    0.4799
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 117 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.35it/s]
# Accuracy:           0.6830    0.7845
# Balanced Accuracy:  0.6818    0.7719
# Precision:          0.7276    0.5676
# Sensitivity/Recall: 0.5737    0.7456
# Specificity:        0.7900    0.7983
# F1 score:           0.6416    0.6445
# MCC:                0.3728    0.5034
# AUC (ROC):          0.7395    0.8446
# AUC (PR):           0.7516    0.6735
# Loss:               3.0240    0.4959
# Epoch 117 (VLD): 100%|| 315/315 [00:01<00:00, 297.40it/s]
# Accuracy:           0.6667    0.8166
# Balanced Accuracy:  0.6641    0.8234
# Precision:          0.6571    0.6000
# Sensitivity/Recall: 0.6174    0.8372
# Specificity:        0.7108    0.8095
# F1 score:           0.6367    0.6990
# MCC:                0.3299    0.5886
# AUC (ROC):          0.7303    0.8808
# AUC (PR):           0.7433    0.7362
# Loss:               3.0815    0.4878
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 118 (TRN): 100%|| 1262/1262 [00:06<00:00, 181.15it/s]
# Accuracy:           0.6846    0.7581
# Balanced Accuracy:  0.6843    0.7598
# Precision:          0.6928    0.5265
# Sensitivity/Recall: 0.6506    0.7633
# Specificity:        0.7179    0.7563
# F1 score:           0.6711    0.6232
# MCC:                0.3694    0.4708
# AUC (ROC):          0.7340    0.8278
# AUC (PR):           0.7487    0.6951
# Loss:               3.0407    0.5115
# Epoch 118 (VLD): 100%|| 315/315 [00:01<00:00, 286.14it/s]
# Accuracy:           0.6698    0.8225
# Balanced Accuracy:  0.6668    0.8273
# Precision:          0.6642    0.6102
# Sensitivity/Recall: 0.6107    0.8372
# Specificity:        0.7229    0.8175
# F1 score:           0.6364    0.7059
# MCC:                0.3360    0.5982
# AUC (ROC):          0.7327    0.8782
# AUC (PR):           0.7469    0.7357
# Loss:               3.0724    0.4842
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 119 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.26it/s]
# Accuracy:           0.6870    0.7721
# Balanced Accuracy:  0.6859    0.7521
# Precision:          0.7258    0.5505
# Sensitivity/Recall: 0.5897    0.7101
# Specificity:        0.7821    0.7941
# F1 score:           0.6508    0.6202
# MCC:                0.3792    0.4687
# AUC (ROC):          0.7358    0.8343
# AUC (PR):           0.7431    0.6862
# Loss:               3.0324    0.4988
# Epoch 119 (VLD): 100%|| 315/315 [00:01<00:00, 300.19it/s]
# Accuracy:           0.6635    0.8166
# Balanced Accuracy:  0.6580    0.8157
# Precision:          0.6748    0.6034
# Sensitivity/Recall: 0.5570    0.8140
# Specificity:        0.7590    0.8175
# F1 score:           0.6103    0.6931
# MCC:                0.3235    0.5792
# AUC (ROC):          0.7329    0.8754
# AUC (PR):           0.7459    0.7341
# Loss:               3.0402    0.4798
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 120 (TRN): 100%|| 1262/1262 [00:06<00:00, 185.39it/s]
# Accuracy:           0.6775    0.7938
# Balanced Accuracy:  0.6761    0.7649
# Precision:          0.7284    0.5891
# Sensitivity/Recall: 0.5545    0.7041
# Specificity:        0.7978    0.8256
# F1 score:           0.6297    0.6415
# MCC:                0.3636    0.5023
# AUC (ROC):          0.7388    0.8377
# AUC (PR):           0.7417    0.6898
# Loss:               3.0399    0.4966
# Epoch 120 (VLD): 100%|| 315/315 [00:01<00:00, 285.31it/s]
# Accuracy:           0.6540    0.8284
# Balanced Accuracy:  0.6511    0.8390
# Precision:          0.6449    0.6167
# Sensitivity/Recall: 0.5973    0.8605
# Specificity:        0.7048    0.8175
# F1 score:           0.6202    0.7184
# MCC:                0.3040    0.6170
# AUC (ROC):          0.7290    0.8738
# AUC (PR):           0.7418    0.7376
# Loss:               3.0827    0.4938
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 121 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.23it/s]
# Accuracy:           0.6870    0.7907
# Balanced Accuracy:  0.6862    0.7723
# Precision:          0.7132    0.5794
# Sensitivity/Recall: 0.6138    0.7337
# Specificity:        0.7586    0.8109
# F1 score:           0.6598    0.6475
# MCC:                0.3766    0.5087
# AUC (ROC):          0.7513    0.8545
# AUC (PR):           0.7640    0.7341
# Loss:               2.9753    0.4773
# Epoch 121 (VLD): 100%|| 315/315 [00:01<00:00, 287.80it/s]
# Accuracy:           0.6603    0.8225
# Balanced Accuracy:  0.6557    0.8273
# Precision:          0.6641    0.6102
# Sensitivity/Recall: 0.5705    0.8372
# Specificity:        0.7410    0.8175
# F1 score:           0.6137    0.7059
# MCC:                0.3166    0.5982
# AUC (ROC):          0.7311    0.8747
# AUC (PR):           0.7447    0.7373
# Loss:               3.0652    0.4833
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 122 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.96it/s]
# Accuracy:           0.6759    0.8233
# Balanced Accuracy:  0.6749    0.7848
# Precision:          0.7079    0.6503
# Sensitivity/Recall: 0.5865    0.7041
# Specificity:        0.7633    0.8655
# F1 score:           0.6415    0.6761
# MCC:                0.3557    0.5557
# AUC (ROC):          0.7314    0.8738
# AUC (PR):           0.7498    0.7350
# Loss:               3.0329    0.4541
# Epoch 122 (VLD): 100%|| 315/315 [00:01<00:00, 289.88it/s]
# Accuracy:           0.6540    0.8284
# Balanced Accuracy:  0.6493    0.8313
# Precision:          0.6562    0.6207
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7349    0.8254
# F1 score:           0.6065    0.7129
# MCC:                0.3036    0.6079
# AUC (ROC):          0.7295    0.8741
# AUC (PR):           0.7454    0.7325
# Loss:               3.0618    0.4845
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 123 (TRN): 100%|| 1262/1262 [00:06<00:00, 182.55it/s]
# Accuracy:           0.6799    0.7922
# Balanced Accuracy:  0.6787    0.7638
# Precision:          0.7236    0.5862
# Sensitivity/Recall: 0.5705    0.7041
# Specificity:        0.7868    0.8235
# F1 score:           0.6380    0.6398
# MCC:                0.3663    0.4996
# AUC (ROC):          0.7260    0.8354
# AUC (PR):           0.7459    0.6692
# Loss:               3.0540    0.5077
# Epoch 123 (VLD): 100%|| 315/315 [00:01<00:00, 291.20it/s]
# Accuracy:           0.6603    0.8284
# Balanced Accuracy:  0.6554    0.8313
# Precision:          0.6667    0.6207
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7470    0.8254
# F1 score:           0.6109    0.7129
# MCC:                0.3167    0.6079
# AUC (ROC):          0.7322    0.8734
# AUC (PR):           0.7477    0.7315
# Loss:               3.0413    0.4854
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 124 (TRN): 100%|| 1262/1262 [00:07<00:00, 180.22it/s]
# Accuracy:           0.6799    0.7860
# Balanced Accuracy:  0.6786    0.7520
# Precision:          0.7254    0.5779
# Sensitivity/Recall: 0.5673    0.6805
# Specificity:        0.7900    0.8235
# F1 score:           0.6367    0.6250
# MCC:                0.3668    0.4798
# AUC (ROC):          0.7335    0.8342
# AUC (PR):           0.7481    0.6789
# Loss:               3.0338    0.5038
# Epoch 124 (VLD): 100%|| 315/315 [00:01<00:00, 289.11it/s]
# Accuracy:           0.6508    0.8284
# Balanced Accuracy:  0.6467    0.8390
# Precision:          0.6489    0.6167
# Sensitivity/Recall: 0.5705    0.8605
# Specificity:        0.7229    0.8175
# F1 score:           0.6071    0.7184
# MCC:                0.2972    0.6170
# AUC (ROC):          0.7344    0.8723
# AUC (PR):           0.7487    0.7306
# Loss:               3.0486    0.4909
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 125 (TRN): 100%|| 1262/1262 [00:06<00:00, 183.74it/s]
# Accuracy:           0.6815    0.7643
# Balanced Accuracy:  0.6805    0.7602
# Precision:          0.7126    0.5359
# Sensitivity/Recall: 0.5962    0.7515
# Specificity:        0.7649    0.7689
# F1 score:           0.6492    0.6256
# MCC:                0.3665    0.4746
# AUC (ROC):          0.7369    0.8494
# AUC (PR):           0.7515    0.7203
# Loss:               3.0168    0.4802
# Epoch 125 (VLD): 100%|| 315/315 [00:01<00:00, 283.33it/s]
# Accuracy:           0.6540    0.8284
# Balanced Accuracy:  0.6493    0.8390
# Precision:          0.6562    0.6167
# Sensitivity/Recall: 0.5638    0.8605
# Specificity:        0.7349    0.8175
# F1 score:           0.6065    0.7184
# MCC:                0.3036    0.6170
# AUC (ROC):          0.7365    0.8760
# AUC (PR):           0.7497    0.7391
# Loss:               3.0387    0.4841
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 126 (TRN): 100%|| 1262/1262 [00:06<00:00, 184.00it/s]
# Accuracy:           0.6688    0.7814
# Balanced Accuracy:  0.6676    0.7660
# Precision:          0.7085    0.5636
# Sensitivity/Recall: 0.5609    0.7337
# Specificity:        0.7743    0.7983
# F1 score:           0.6261    0.6375
# MCC:                0.3434    0.4935
# AUC (ROC):          0.7290    0.8436
# AUC (PR):           0.7525    0.7276
# Loss:               3.0319    0.4841
# Epoch 126 (VLD): 100%|| 315/315 [00:01<00:00, 314.12it/s]
# Accuracy:           0.6508    0.8225
# Balanced Accuracy:  0.6463    0.8273
# Precision:          0.6512    0.6102
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7289    0.8175
# F1 score:           0.6043    0.7059
# MCC:                0.2972    0.5982
# AUC (ROC):          0.7348    0.8745
# AUC (PR):           0.7487    0.7363
# Loss:               3.0334    0.4816
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# Epoch 127 (TRN): 100%|| 1262/1262 [00:06<00:00, 184.85it/s]
# Accuracy:           0.6846    0.7845
# Balanced Accuracy:  0.6835    0.7662
# Precision:          0.7278    0.5694
# Sensitivity/Recall: 0.5785    0.7278
# Specificity:        0.7884    0.8046
# F1 score:           0.6446    0.6390
# MCC:                0.3756    0.4961
# AUC (ROC):          0.7372    0.8438
# AUC (PR):           0.7585    0.6948
# Loss:               2.9920    0.4887
# Epoch 127 (VLD): 100%|| 315/315 [00:01<00:00, 276.04it/s]
# Accuracy:           0.6540    0.8343
# Balanced Accuracy:  0.6493    0.8353
# Precision:          0.6562    0.6316
# Sensitivity/Recall: 0.5638    0.8372
# Specificity:        0.7349    0.8333
# F1 score:           0.6065    0.7200
# MCC:                0.3036    0.6177
# AUC (ROC):          0.7354    0.8767
# AUC (PR):           0.7490    0.7384
# Loss:               3.0312    0.4790
# model_ckpt_finetune.pt
# Best AUC (ROC): 0.8161198906830096
# Best AUC (PR): 0.7463508877991373
# ADRDModel(_dataloader_num_workers=1, batch_size=128,
#           ckpt_path='./dev/ckpt/model_ckpt_finetune.pt', criterion='AUC (ROC)',
#           cuda_devices=[1, 2], d_model=256, gamma=2, img_net='NonImg',
#           imgnet_layers=4,
#           label_distribution={'amy_label': {0: 804, 1: 773},
#                               'tau_label': {0.0: 602, 1.0: 212}},
#           label_fractions={'amy_label': 0.49445324881141045,
#                            'tau_label': 0.13391442155309033},
#           l...
#                           'bat_NACCMOCA': {'shape': [1], 'type': 'numerical'},
#                           'cd_DIAGNOSIS': {'num_categories': 3,
#                                            'type': 'categorical'},
#                           'cdr_CDRGLOB': {'shape': [1], 'type': 'numerical'},
#                           'cdr_CDRSUM': {'shape': [1], 'type': 'numerical'}, ...},
#           tgt_modalities={'amy_label': {'num_categories': 2,
#                                         'type': 'categorical'},
#                           'tau_label': {'num_categories': 2,
#                                         'type': 'categorical'}},
#           verbose=4, wandb_=1, weight_decay=0.01)
